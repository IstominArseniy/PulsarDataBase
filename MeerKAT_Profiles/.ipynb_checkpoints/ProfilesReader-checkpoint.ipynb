# %%
pip install astropy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 4.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 5.2 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
import numpy as np
from astropy.io import fits

# %%
PSR_DATA = dict()

# %%
hdul = fits.open('ar_files/J0729-1448_2019-11-12-22:50:48_zap.8chTS.fluxcal.ar')

# %%
hdul.info()
# Out:
# Filename: ar_files/J0729-1448_2019-11-12-22:50:48_zap.8chTS.fluxcal.ar
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      64   ()
#   1  HISTORY       1 BinTableHDU     74   9R x 29C   [24A, 256A, 8A, 8A, 1J, 1I, 1I, 1I, 1D, 1D, 1J, 1D, 1D, 1D, 1D, 1I, 1I, 1I, 1I, 1I, 32A, 32A, 32A, 256A, 32A, 32A, 1I, 32A, 1I]
#   2  PSRPARAM      1 BinTableHDU     12   32R x 1C   [128A]
#   3  T2PREDICT     1 BinTableHDU     12   22R x 1C   [128A]
#   4  SUBINT        1 BinTableHDU     92   1R x 21C   [1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1D, 1E, 1E, 1E, 1E, 1E, 1D, 1D, 8D, 8E, 32E, 32E, 32768I]

# %%
stocksData = hdul[4].data['DATA'][0]
stocksData.shape
# Out:
# (4, 8, 1024)

# %%
for i in range(8):
    plt.plot(stocksData[0][i][512:-10])

# %%
plt.plot(stocksData[0][i])
